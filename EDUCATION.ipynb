# %%
import pandas as pd

# Load the Excel dataset
df = pd.read_excel(r'C:\Users\isai5\OneDrive\Documentos\Github\databases\Educacion_04.xlsx')
df.head()
# Out:
#          Entidad federativa        Total  Sin escolaridad  Preescolar  \
# 0  Estados Unidos Mexicanos  119976584.0        7701507.0   6110435.0
# 1            Aguascalientes    1352235.0          63957.0     72236.0
# 2           Baja California    3610844.0         180275.0    155091.0
# 3       Baja California Sur     758642.0          36121.0     38810.0
# 4                  Campeche     878528.0          68195.0     49037.0
#
#      Primaria  Secundaria  \
# 0  33253208.0  29426059.0
# 1    346807.0    361191.0
# 2    872803.0    945609.0
# 3    184093.0    182005.0
# 4    233844.0    218926.0
#
#    Estudios técnicos o comerciales con primaria terminada  \
# 0                                           354724.0
# 1                                             4705.0
# 2                                            12001.0
# 3                                             2653.0
# 4                                             1948.0
#
# ...

# %%
df.describe()
# Out:
#               Total  Sin escolaridad    Preescolar      Primaria  \
# count  3.300000e+01     3.300000e+01  3.300000e+01  3.300000e+01
# mean   7.271308e+06     4.667580e+05  3.703294e+05  2.015346e+06
# std    2.046704e+07     1.314428e+06  1.040728e+06  5.668990e+06
# min    6.998210e+05     3.612100e+04  3.438900e+04  1.840930e+05
# 25%    1.752570e+06     1.005440e+05  9.246300e+04  4.850230e+05
# 50%    2.944897e+06     1.612590e+05  1.510330e+05  7.904710e+05
# 75%    5.181929e+06     3.854540e+05  2.767470e+05  1.562083e+06
# max    1.199766e+08     7.701507e+06  6.110435e+06  3.325321e+07
#
#          Secundaria  Estudios técnicos o comerciales con primaria terminada  \
# count  3.300000e+01                                          33.000000
# mean   1.783398e+06                                       21498.424242
# std    5.021305e+06                                       60877.164154
# min    1.697140e+05                                        1748.000000
# ...

# %%
df[df.apply(lambda row: row.astype(str).str.contains('Zacatecas', case=False).any(), axis=1)]
# Out:
#    Entidad federativa      Total  Sin escolaridad  Preescolar  Primaria  \
# 32          Zacatecas  1531847.0          86754.0     91857.0  477523.0
#
#     Secundaria  Estudios técnicos o comerciales con primaria terminada  \
# 32    444866.0                                             3870.0
#
#     Estudios técnicos o comerciales con secundaria terminada  \
# 32                                            10874.0
#
#     Preparatoria o bachillerato  Normal básica  \
# 32                     208293.0         1581.0
#
#     Estudios técnicos o comerciales con preparatoria terminada  \
# 32                                            12930.0
#
#     Licenciatura o equivalente  Posgrado  No especificado
# 32                    164956.0   25217.0           3126.0
